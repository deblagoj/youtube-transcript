# %%
from youtube_transcript_api import YouTubeTranscriptApi

YouTubeTranscriptApi.get_transcript('iS3te7kM6DY')
# Out:
# [{'text': 'yeehaw', 'start': 1.25, 'duration': 4.9},
#  {'text': 'hey hanging in there fella great man I',
#   'start': 3.38,
#   'duration': 5.799},
#  {'text': 'think these things are gonna annoy a lot',
#   'start': 6.15,
#   'duration': 5.31},
#  {'text': "of people if you're listening we're",
#   'start': 9.179,
#   'duration': 5.88},
#  {'text': "wearing a luminol we're wearing", 'start': 11.46, 'duration': 6.18},
#  {'text': "spacesuits yeah god they're so crunchy",
#   'start': 15.059,
#   'duration': 4.291},
#  {'text': "there's not many left for me to get this",
#   'start': 17.64,
#   'duration': 4.979},
#  {'text': 'is the yeah this is my favorite one I',
#   'start': 19.35,
#   'duration': 5.25},
#  {'text': 'like the orange one for some strange',
#   'start': 22.619,
#   'duration': 3.57},
#  {'text': "reason the white one just seems like I'm",
#   'start': 24.6,
#   'duration': 4.14},
#  {'text': "a cleanup person you know like you're",
#   'start': 26.189,
# ...
